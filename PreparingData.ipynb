# %%
import pandas as pd

# %%
weather_raw = pd.read_csv("./data/HistoryDataWeatherToronto.csv")

# %%
weather_raw.head(10)
# Out:
#            dt                         dt_iso  timezone city_name        lat  \
# 0  1684281600  2023-05-17 00:00:00 +0000 UTC    -14400   Toronto  43.653226
# 1  1684285200  2023-05-17 01:00:00 +0000 UTC    -14400   Toronto  43.653226
# 2  1684288800  2023-05-17 02:00:00 +0000 UTC    -14400   Toronto  43.653226
# 3  1684292400  2023-05-17 03:00:00 +0000 UTC    -14400   Toronto  43.653226
# 4  1684296000  2023-05-17 04:00:00 +0000 UTC    -14400   Toronto  43.653226
# 5  1684299600  2023-05-17 05:00:00 +0000 UTC    -14400   Toronto  43.653226
# 6  1684303200  2023-05-17 06:00:00 +0000 UTC    -14400   Toronto  43.653226
# 7  1684306800  2023-05-17 07:00:00 +0000 UTC    -14400   Toronto  43.653226
# 8  1684310400  2023-05-17 08:00:00 +0000 UTC    -14400   Toronto  43.653226
# 9  1684314000  2023-05-17 09:00:00 +0000 UTC    -14400   Toronto  43.653226
#
#          lon   temp  visibility  dew_point  feels_like  ...  wind_gust  \
# 0 -79.383184  15.14     10000.0       7.19       14.25  ...      12.86
# 1 -79.383184  12.97     10000.0       5.40       11.89  ...      10.80
# 2 -79.383184  11.63     10000.0       3.90       10.39  ...       9.26
# 3 -79.383184  10.07     10000.0       2.90        8.73  ...      13.38
# 4 -79.383184   8.97     10000.0       1.86        5.88  ...        NaN
# 5 -79.383184   7.95     10000.0       0.20        4.09  ...      11.83
# 6 -79.383184   6.84     10000.0      -0.33        2.65  ...      10.80
# 7 -79.383184   5.72     10000.0      -0.49        1.37  ...      10.29
# 8 -79.383184   4.43     10000.0      -0.84        1.09  ...        NaN
# 9 -79.383184   3.59     10000.0      -1.73        0.05  ...        NaN
#
#    rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN      NaN      NaN           0         800         Clear
# 1      NaN      NaN      NaN      NaN           0         800         Clear
# 2      NaN      NaN      NaN      NaN           0         800         Clear
# 3      NaN      NaN      NaN      NaN           0         800         Clear
# 4      NaN      NaN      NaN      NaN           0         800         Clear
# 5      NaN      NaN      NaN      NaN           0         800         Clear
# 6      NaN      NaN      NaN      NaN           0         800         Clear
# 7      NaN      NaN      NaN      NaN          20         801        Clouds
# 8      NaN      NaN      NaN      NaN          40         802        Clouds
# 9      NaN      NaN      NaN      NaN          20         801        Clouds
#
#    weather_description  weather_icon
# 0         sky is clear           01d
# 1         sky is clear           01n
# 2         sky is clear           01n
# 3         sky is clear           01n
# 4         sky is clear           01n
# 5         sky is clear           01n
# 6         sky is clear           01n
# 7           few clouds           02n
# 8     scattered clouds           03n
# 9           few clouds           02n
#
# [10 rows x 28 columns]

# %%
city_df = weather_raw.groupby("city_name")
toronto_full_df = city_df.get_group("Toronto")

# %%
toronto_df = toronto_full_df[["dt_iso", "weather_id"]]

# %%
merge_df = pd.merge(weather_raw, toronto_df, on='dt_iso', how='left')
merge_df = merge_df.drop(merge_df[merge_df["city_name"] == 'Toronto'].index)

# %%
weather_sorted = merge_df.sort_values(by=['dt_iso'])
weather_sorted.head(100)
# Out:
#                dt                         dt_iso  timezone      city_name  \
# 9776   1684281600  2023-05-17 00:00:00 +0000 UTC    -14400         Barrie
# 28375  1684281600  2023-05-17 00:00:00 +0000 UTC    -14400  Niagara Falls
# 37987  1684281600  2023-05-17 00:00:00 +0000 UTC    -14400      Kitchener
# 18896  1684281600  2023-05-17 00:00:00 +0000 UTC    -14400   Peterborough
# 18897  1684285200  2023-05-17 01:00:00 +0000 UTC    -14400   Peterborough
# ...           ...                            ...       ...            ...
# 18919  1684364400  2023-05-17 23:00:00 +0000 UTC    -14400   Peterborough
# 38011  1684368000  2023-05-18 00:00:00 +0000 UTC    -14400      Kitchener
# 28399  1684368000  2023-05-18 00:00:00 +0000 UTC    -14400  Niagara Falls
# 9800   1684368000  2023-05-18 00:00:00 +0000 UTC    -14400         Barrie
# 18920  1684368000  2023-05-18 00:00:00 +0000 UTC    -14400   Peterborough
#
#              lat        lon   temp  visibility  dew_point  feels_like  ...  \
# 9776   44.389356 -79.690332  10.00         NaN       3.73        7.03  ...
# 28375  43.089558 -79.084944  15.11     10000.0       7.41       14.24  ...
# 37987  43.451639 -80.492534  12.52     10000.0       7.41       11.68  ...
# 18896  44.304706 -78.319961  10.39     10000.0       4.32        9.21  ...
# 18897  44.304706 -78.319961   8.14     10000.0       2.18        4.49  ...
# ...          ...        ...    ...         ...        ...         ...  ...
# 18919  44.304706 -78.319961  10.26     10000.0      -5.81        8.12  ...
# 38011  43.451639 -80.492534   9.70     10000.0      -4.78        9.27  ...
# 28399  43.089558 -79.084944   9.58     10000.0      -2.10        7.68  ...
# 9800   44.389356 -79.690332   5.85         NaN      -1.56        3.46  ...
# 18920  44.304706 -78.319961   7.60     10000.0      -4.84        5.93  ...
#
#        rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id_x  \
# 9776       NaN      NaN      NaN      NaN          78           803
# 28375      NaN      NaN      NaN      NaN          75           803
# 37987      NaN      NaN      NaN      NaN           0           800
# 18896      NaN      NaN      NaN      NaN          40           802
# 18897      NaN      NaN      NaN      NaN          75           803
# ...        ...      ...      ...      ...         ...           ...
# 18919      NaN      NaN      NaN      NaN           0           800
# 38011      NaN      NaN      NaN      NaN           0           800
# 28399      NaN      NaN      NaN      NaN           0           800
# 9800       NaN      NaN      NaN      NaN           0           800
# 18920      NaN      NaN      NaN      NaN           0           800
#
#        weather_main  weather_description  weather_icon  weather_id_y
# 9776         Clouds        broken clouds           04d           800
# 28375        Clouds        broken clouds           04d           800
# 37987         Clear         sky is clear           01d           800
# 18896        Clouds     scattered clouds           03d           800
# 18897        Clouds        broken clouds           04n           800
# ...             ...                  ...           ...           ...
# 18919         Clear         sky is clear           01d           800
# 38011         Clear         sky is clear           01d           800
# 28399         Clear         sky is clear           01d           800
# 9800          Clear         sky is clear           01d           800
# 18920         Clear         sky is clear           01d           800
#
# [100 rows x 29 columns]

# %%
weather_sorted[['dt_iso', 'city_name','weather_id_x', 'weather_id_y']]
# Out:
#                               dt_iso      city_name  weather_id_x  \
# 9776   2023-05-17 00:00:00 +0000 UTC         Barrie           803
# 28375  2023-05-17 00:00:00 +0000 UTC  Niagara Falls           803
# 37987  2023-05-17 00:00:00 +0000 UTC      Kitchener           800
# 18896  2023-05-17 00:00:00 +0000 UTC   Peterborough           802
# 18897  2023-05-17 01:00:00 +0000 UTC   Peterborough           803
# ...                              ...            ...           ...
# 18894  2024-05-17 22:00:00 +0000 UTC         Barrie           500
# 28374  2024-05-17 23:00:00 +0000 UTC   Peterborough           803
# 37986  2024-05-17 23:00:00 +0000 UTC  Niagara Falls           804
# 18895  2024-05-17 23:00:00 +0000 UTC         Barrie           800
# 47605  2024-05-17 23:00:00 +0000 UTC      Kitchener           803
#
#        weather_id_y
# 9776            800
# 28375           800
# 37987           800
# 18896           800
# 18897           800
# ...             ...
# 18894           500
# 28374           804
# 37986           804
# 18895           804
# 47605           804
#
# [37830 rows x 4 columns]

# %%
merge_df.to_csv('./data/WeatherData_TorontoLabel.csv', index=False ,sep=',', header=True, encoding='utf-8')
weather_sorted.to_csv('./data/SortedWeatherData_TorontoLabel.csv', index=False ,sep=',', header=True, encoding='utf-8')
